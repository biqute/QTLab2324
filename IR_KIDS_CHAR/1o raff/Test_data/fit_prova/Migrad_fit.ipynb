# %%
from iminuit import cost, Minuit
# faster than scipy.stats functions
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import multivariate_normal as mvnorm
import scipy

# %%
xr = (0, 2)  # xrange

rng = np.random.default_rng(1)

xdata = rng.normal(1, 0.1, size=1000)
ydata = rng.exponential(size=len(xdata))
xmix = np.append(xdata, ydata)
xmix = xmix[(xr[0] < xmix) & (xmix < xr[1])]

n, xe = np.histogram(xmix, bins=20, range=xr)
cx = 0.5 * (xe[1:] + xe[:-1])
dx = np.diff(xe)

plt.errorbar(cx, n, n ** 0.5, fmt="ok")
plt.plot(xmix, np.zeros_like(xmix), "|", alpha=0.1);(1)

def model(x, a, b):
    return a + b * x

truth = (1., 2.)
x = np.linspace(0, 1)
ym = model(x, *truth)
ye = 0.1
y = rng.normal(ym, ye)

c = cost.LeastSquares(x, y, ye, model)

m = Minuit(c, *truth)

# %%
c = cost.UnbinnedNLL(xmix, scipy.stats.norm.pdf(x))

m = Minuit(c, z=0.4, mu=0.1, sigma=0.2, tau=2)
m.limits["z"] = (0, 1)
m.limits["sigma", "tau"] = (0, None)
m.migrad()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 c = cost.UnbinnedNLL(xmix, scipy.stats.norm.pdf(x))
#       3 m = Minuit(c, z=0.4, mu=0.1, sigma=0.2, tau=2)
#       4 m.limits["z"] = (0, 1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\iminuit\cost.py:937, in UnbinnedNLL.__init__(self, data, pdf, verbose, log)
#     906 def __init__(
#     907     self,
#     908     data: ArrayLike,
#    (...)
#     911     log: bool = False,
#     912 ):
#     913     """
#     914     Initialize UnbinnedNLL with data and model.
#     915
#    (...)
#     935         Default is False.
#     936     """
# --> 937     super().__init__(data, pdf, verbose, log)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\iminuit\cost.py:811, in UnbinnedCost.__init__(self, data, model, verbose, log)
#     809 self._model = model
#     810 self._log = log
# --> 811 super().__init__(_model_parameters(model), _norm(data), verbose)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\iminuit\cost.py:2069, in _model_parameters(model)
#    2067 def _model_parameters(model):
#    2068     # strip first argument from model
# -> 2069     ann = describe(model, annotations=True)
#    2070     args = iter(ann)
#    2071     next(args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\iminuit\util.py:1229, in describe(callable, annotations)
#    1223 if _address_of_cfunc(callable) != 0:
#    1224     return {} if annotations else []
#    1226 args = (
#    1227     getattr(callable, "_parameters", {})
#    1228     or _arguments_from_func_code(callable)
# -> 1229     or _parameters_from_inspect(callable)
#    1230     or _arguments_from_docstring(callable)
#    1231 )
#    1233 if annotations:
#    1234     return args
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\iminuit\util.py:1300, in _parameters_from_inspect(callable)
#    1298 def _parameters_from_inspect(callable):
#    1299     try:
# -> 1300         signature = inspect.signature(callable)
#    1301     except ValueError:  # raised when used on built-in function
#    1302         return {}
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.496.0_x64__qbz5n2kfra8p0\Lib\inspect.py:3327, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3325 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3326     """Get a signature object for the passed callable."""
# -> 3327     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3328                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.496.0_x64__qbz5n2kfra8p0\Lib\inspect.py:3071, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3067 @classmethod
#    3068 def from_callable(cls, obj, *,
#    3069                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3070     """Constructs Signature for the given callable object."""
# -> 3071     return _signature_from_callable(obj, sigcls=cls,
#    3072                                     follow_wrapper_chains=follow_wrapped,
#    3073                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.496.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2484, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2475 _get_signature_of = functools.partial(_signature_from_callable,
#    2476                             follow_wrapper_chains=follow_wrapper_chains,
#    2477                             skip_bound_arg=skip_bound_arg,
#    (...)
#    2480                             sigcls=sigcls,
#    2481                             eval_str=eval_str)
#    2483 if not callable(obj):
# -> 2484     raise TypeError('{!r} is not a callable object'.format(obj))
#    2486 if isinstance(obj, types.MethodType):
#    2487     # In this case we skip the first parameter of the underlying
#    2488     # function (usually `self` or `cls`).
#    2489     sig = _get_signature_of(obj.__func__)
#
# TypeError: array([0.39894228, 0.39885921, 0.39861011, 0.39819528, 0.39761524,
#        0.39687072, 0.39596264, 0.39489214, 0.39366054, 0.39226937,
#        0.39072035, 0.38901539, 0.38715659, 0.38514623, 0.38298676,
#        0.38068082, 0.37823119, 0.37564085, 0.37291289, 0.37005059,
#        0.36705736, 0.36393672, 0.36069236, 0.35732807, 0.35384775,
#        0.35025541, 0.34655518, 0.34275126, 0.33884794, 0.33484957,
#        0.3307606 , 0.3265855 , 0.32232884, 0.31799518, 0.31358916,
#        0.30911541, 0.30457861, 0.29998342, 0.29533453, 0.29063661,
#        0.28589432, 0.28111231, 0.27629519, 0.27144753, 0.26657387,
#        0.26167871, 0.25676648, 0.25184154, 0.24690821, 0.24197072]) is not a callable object
