# %%
import IPython
import HP8753E as hp
import numpy as np
import pyvisa

# %%
VNA = hp.HP8753E()
# Out:
# Creating the object
# VNA object created correctly!
#
# Default number of points for a sweep: 1601

# %%
VNA.set_params()

# %%
i, q, f = VNA.get_IQF_single_meas()

# %%
VNA.create_run_file(31,i,q,f)

# %%
print(len(i))
print(len(q))
# Out:
# 1601
# 1601
