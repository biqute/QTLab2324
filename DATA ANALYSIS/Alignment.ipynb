# %%
from UTILS.load_data import get_data, in_memory

# %% [markdown]
# Get data from Google Drive

# %%
files, svc = get_data(max_files=2)

# %%
data = in_memory(files[0], svc)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Plot Raw Data

# %%
Timestamp = np.linspace(0,len(data),len(data),dtype=int)

# %%
plt.figure(figsize=(20,5))
plt.plot(Timestamp,data)
plt.title('RAW  I SIGNAL')
plt.ylabel('[V]')
plt.xlabel('Timestamp')
# Out:
# Text(0.5, 0, 'Timestamp')

# %% [markdown]
# Cut data

# %%
idx = np.array(Timestamp[:int(0.4*1e6)])
T = Timestamp[idx]
I = data[idx]

# %%
plt.figure(figsize=(20,5))
plt.plot(T,I)
plt.title('CUT I SIGNAL')
plt.ylabel('[V]')
plt.xlabel('Timestamp')
# Out:
# Text(0.5, 0, 'Timestamp')

# %% [markdown]
# Trigger

# %%
from UTILS.Trigger import derivative_trigger, align_signal

# %%
a,b,_ = derivative_trigger(data,100,plot=True)

# %%
final, minp = align_signal(data,100,1000,20000)

# %%
T_final = np.linspace(0,len(final),len(final))

# %%
plt.plot(final)
