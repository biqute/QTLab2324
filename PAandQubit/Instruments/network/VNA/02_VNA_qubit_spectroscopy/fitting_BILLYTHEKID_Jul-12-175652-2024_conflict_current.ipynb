# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import sys 
sys.path.insert(0, r'C:\Users\oper\SynologyDrive\Lab2023\KIDs\QTLab2324\PAandQubit\Actual_Work')
import FunFit as FF
import Tuls as Ts

# %%
file_path = r'C:\Users\oper\SynologyDrive\Lab2023\KIDs\QTLab2324\PAandQubit\Instruments\network\VNA\02_VNA_qubit_spectroscopy\q_spec_200624.h5'

file_dict = Ts.load_hdf5_to_dict(file_path)

amps = file_dict['q_spec']
freqs = file_dict['f_range']

plt.plot(freqs,amps)
plt.show()

param, param_cov = curve_fit(FF.Lorentzian, freqs, amps)
# Out:
# c:\Users\oper\SynologyDrive\Lab2023\Qubit\qubit2324\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
