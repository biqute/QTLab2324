# %%
# Configure the integration and enable interactive mode
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from iminuit import Minuit
from iminuit.cost import LeastSquares
from FunFit import *
# Out:
# C:\Users\fsfinardi\AppData\Local\Temp\ipykernel_15556\976303620.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # qubit_spec_20230801

# %%
# C:\Users\oper\SynologyDrive\Lab2023\Qubit\data\qubit_spectroscopy\qubit_spec_20230801\data\qubit spectroscopy_0\data.npz

file = np.load("C:\\Users\\fsfinardi\\Documents\\01_Personali\\Università-2324\\LabCrio\\data\\qubit_spectroscopy\\qubit_spec_20230801\\data\\qubit spectroscopy_0\\data.npz")
# file = np.load("C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\qubit_spectroscopy\\qubit_spec_20230801\\data\\qubit spectroscopy_0\\data.npz")
print(file.files)
# Out:
# ['D1', 'D2', 'D3']

# %%
D1 = file['D1']
D2 = file['D2']
D3 = file['D3']

print(D1.dtype)
D1_freq = D1['freq']
D1_msr = D1['msr']
D1_phase = D1['phase']
# Out:
# [('freq', '<f8'), ('msr', '<f8'), ('phase', '<f8')]

# %% [markdown]
# ## Qubit_D1 - Frequency vs MSR and Frequency vs Phase

# %% [markdown]
# Qui misuro risonatore accoppiato a uno dei due stati, in funzione della freq inviata  al Qubit. Ricordarsi SHIFT DEL RISONATORE

# %%
plt.figure()
plt.subplot(211)
plt.plot(D1_freq, D1_msr)
plt.subplot(212)
plt.plot(D1_freq, D1_phase)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Moving Avarage

# %%
window_size = 3
x, y = moving_avg(D1_freq, D1_msr, window_size).values()

plt.figure()
plt.plot(x, y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Setting the initial values for the fit

# %%
D1_min = min(y)
D1_max = max(y)
idx_max = y.index(max(y))
D1_peak = x[idx_max]

half_height = (D1_max + D1_min)/2

argMax = np.argmax(y)
idx_L = np.argmin(np.abs(half_height - np.array(y[:argMax])))
idx_R = np.argmin(np.abs(half_height - np.array(y[argMax:]))) + (idx_max + 1)

fig = plt.figure()
plt.plot(x, y)
plt.plot([x[idx_L],x[idx_R]], [y[idx_L],y[idx_R]], ls = 'none', marker = 'o')

D1_gamma = x[idx_R] - x[idx_L]
plt.show()

print('Minimum:', D1_min)
print('Maximum:', D1_max)
print('f peak:', D1_peak)
print('Gamma:', D1_gamma/1e9)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Minimum: 0.40036485233466035
# Maximum: 2.2385056480772256
# f peak: 4941124214.0
# Gamma: 0.0038

# %% [markdown]
# ## Fit with "best" parameters found

# %%
x_c, y_c = data_cut(x, y, 4.930e9, 4.952e9).values()

# Amplitude, x0, Gamma, Minimum
pars = [D1_max, D1_peak, D1_gamma/4, D1_min+0.1]

pars_opt = fit(x_c, y_c, 1, Lorentzian, pars)

plt.figure()
plt.plot(x_c, y_c, marker = '.', linewidth = 1)   
plt.plot(x_c, Lorentzian(x_c, pars))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pars_2 = [D1_max, D1_peak, D1_min]

par_opt_2 = fit(x, y, 0.5, Sinc, pars_2)

plt.figure()
plt.plot(x, y, marker = '.', linewidth = 1)   
plt.plot(x, Sinc(x, par_opt_2))
plt.plot(x, D1_min + np.sinc(x - D1_peak))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
