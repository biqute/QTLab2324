# %%
# %matplotlib widget

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from FunFit import *
# Out:
# C:\Users\fsfinardi\AppData\Local\Temp\ipykernel_2952\2831617652.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\classification\\class_20230801\\data\\classification_0\\data.npz"

dir_path = "C:\\Users\\fsfinardi\\Documents\\01_Personali\\Università-2324\\LabCrio\\data\\classification"
# dir_path = "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\classification"

files = os.listdir(dir_path)
for name in files:
    print(f'Directory {files.index(name)}: {name}')


n_dir = 0

file = np.load(f"{dir_path}\\{files[n_dir]}\\data\\classification_0\\data.npz")
print('\n', file.files)
# Out:
# Directory 0: class_20230801
# Directory 1: class_20230803
# Directory 2: class_20230809
#
#  ["('D1', 0)", "('D2', 0)", "('D3', 0)", "('D1', 1)", "('D2', 1)", "('D3', 1)"]

# %%
Nx = file.files[0]
print(Nx)
print(file[Nx].dtype)
name_data = Nx

I    = file[name_data]['i']
Q     = file[name_data]['q']
# Out:
# ('D1', 0)
# [('i', '<f8'), ('q', '<f8')]

# %% [markdown]
# ## Amplitude vs MSR and Amplitude vs Phase

# %%
plt.figure()
plt.plot(I, Q, ls = 'none', marker = '.')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
window_size = 3
x, y = moving_avg(amp, msr, window_size).values()

plt.figure()
plt.plot(x, y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
