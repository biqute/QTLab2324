# %%
# %matplotlib widget

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from FunFit import *
# Out:
# C:\Users\fsfinardi\AppData\Local\Temp\ipykernel_8268\2831617652.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\rabi\\rabi_20230801\\data\\rabi_0\\data.npz"

dir_path = "C:\\Users\\fsfinardi\\Documents\\01_Personali\\Università-2324\\LabCrio\\data\\rabi"
# dir_path = "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\rabi"

files = os.listdir(dir_path)
for name in files:
    print(f'Directory {files.index(name)}: {name}')


n_dir = 0

file = np.load(f"{dir_path}\\{files[n_dir]}\\data\\rabi_0\\data.npz")
print('\n', file.files)
# Out:
# Directory 0: 20230713_rabi_LATEST
# Directory 1: rabi_20230801
#
#  ['0', '1']

# %%
Nx = file.files[0]
print(Nx)
print(file[Nx].dtype)
name_data = Nx

amp    = file[name_data]['amp']
msr     = file[name_data]['msr']
phase   = file[name_data]['phase']
# Out:
# 0
# [('amp', '<f8'), ('msr', '<f8'), ('phase', '<f8')]

# %% [markdown]
# ## Amplitude vs MSR and Amplitude vs Phase

# %%
plt.figure()
plt.subplot(211)
plt.plot(amp, msr)
plt.subplot(212)
plt.plot(amp, phase)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pars_opt, err_cov = curve_fit(np.sin(msr,pars)**2, msr, amp, pars)
plt.figure()
plt.plot(x_c, y_c, marker = '.', linewidth = 1)   
plt.plot(x_c, Lorentzian(x_c, *pars_opt))
