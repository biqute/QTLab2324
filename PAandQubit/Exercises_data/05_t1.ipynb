# %%
# %matplotlib widget

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from FunFit import *
# Out:
# C:\Users\fsfinardi\AppData\Local\Temp\ipykernel_19920\2831617652.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\t1\\t1_20230801\\data\\t1_0\\data.npz"

dir_path = "C:\\Users\\fsfinardi\\Documents\\01_Personali\\Università-2324\\LabCrio\\data\\t1"
# dir_path = "C:\\Users\\oper\\SynologyDrive\\Lab2023\\Qubit\\data\\rabi"

files = os.listdir(dir_path)
for name in files:
    print(f'Directory {files.index(name)}: {name}')


n_dir = 0

file = np.load(f"{dir_path}\\{files[n_dir]}\\data\\t1_0\\data.npz")
print('\n', file.files)
# Out:
# Directory 0: t1_20230801
# Directory 1: t1_20230803
#
#  ['D1', 'D2', 'D3']

# %%
Dx = file.files[0]
print(Dx)
print(file[Dx].dtype)
name_data = Dx

wait    = file[name_data]['wait']
msr     = file[name_data]['msr']
phase   = file[name_data]['phase']
# Out:
# D1
# [('wait', '<f8'), ('msr', '<f8'), ('phase', '<f8')]

# %% [markdown]
# ## Amplitude vs MSR and Amplitude vs Phase

# %%
plt.figure()
plt.subplot(211)
plt.plot(wait, msr)
plt.subplot(212)
plt.plot(wait, phase)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
